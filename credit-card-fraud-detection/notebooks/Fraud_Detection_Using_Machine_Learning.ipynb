# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

# %matplotlib inline
sns.set()
warnings.simplefilter('ignore')

# %%
data = pd.read_csv('data/creditcard.csv')
creditcard_data = data.copy();

# %% [markdown]
# ###########################################
# ## Data Exploration and Analysis ##
# ###########################################

# %% [markdown]
# ## Checking the columns and sample records.

# %%
print(creditcard_data.columns)
creditcard_data.head()
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'Class'],
#       dtype='object')
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
# 3 -0.221929  0.062723  0.061458  123.50      0
# 4  0.502292  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %% [markdown]
# ## Checking the shape of the dataframe and null values.

# %%
print(creditcard_data.shape)
print(creditcard_data.isnull().sum())
# Out:
# (284807, 31)
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %% [markdown]
# ## Description of the data.

# %%
print(creditcard_data.describe())
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# std    1.380247e+00  1.332271e+00  1.237094e+00  1.194353e+00  1.098632e+00
# min   -1.137433e+02 -2.616051e+01 -4.355724e+01 -7.321672e+01 -1.343407e+01
# 25%   -6.915971e-01 -7.682956e-01 -5.540759e-01 -2.086297e-01 -6.430976e-01
# 50%   -5.433583e-02 -2.741871e-01  4.010308e-02  2.235804e-02 -5.142873e-02
# 75%    6.119264e-01  3.985649e-01  5.704361e-01  3.273459e-01  5.971390e-01
# max    3.480167e+01  7.330163e+01  1.205895e+02  2.000721e+01  1.559499e+01
#
#        ...           V21           V22           V23           V24  \
# count  ...  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   ...  1.654067e-16 -3.568593e-16  2.578648e-16  4.473266e-15
# std    ...  7.345240e-01  7.257016e-01  6.244603e-01  6.056471e-01
# min    ... -3.483038e+01 -1.093314e+01 -4.480774e+01 -2.836627e+00
# 25%    ... -2.283949e-01 -5.423504e-01 -1.618463e-01 -3.545861e-01
# 50%    ... -2.945017e-02  6.781943e-03 -1.119293e-02  4.097606e-02
# 75%    ...  1.863772e-01  5.285536e-01  1.476421e-01  4.395266e-01
# max    ...  2.720284e+01  1.050309e+01  2.252841e+01  4.584549e+00
#
#                 V25           V26           V27           V28         Amount  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  284807.000000
# mean   5.340915e-16  1.683437e-15 -3.660091e-16 -1.227390e-16      88.349619
# std    5.212781e-01  4.822270e-01  4.036325e-01  3.300833e-01     250.120109
# min   -1.029540e+01 -2.604551e+00 -2.256568e+01 -1.543008e+01       0.000000
# 25%   -3.171451e-01 -3.269839e-01 -7.083953e-02 -5.295979e-02       5.600000
# 50%    1.659350e-02 -5.213911e-02  1.342146e-03  1.124383e-02      22.000000
# 75%    3.507156e-01  2.409522e-01  9.104512e-02  7.827995e-02      77.165000
# max    7.519589e+00  3.517346e+00  3.161220e+01  3.384781e+01   25691.160000
#
#                Class
# count  284807.000000
# mean        0.001727
# std         0.041527
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000
#
# [8 rows x 31 columns]

# %% [markdown]
# ## Checking the Fraud counts using the Class identifier

# %%
print("**************************************")
print(":: Class Distribution ::")
print(creditcard_data.Class.value_counts())
print("**************************************")
Fraudulent_Transactions = creditcard_data[creditcard_data['Class'] == 1]
Valid_Transactions = creditcard_data[creditcard_data['Class'] == 0]

print("**************************************")
print(":: Description of Amount for Fraudulent Transactions :: \n" , Fraudulent_Transactions['Amount'].describe())
print("**************************************")
print(":: Description of Amount for Valid Transactions :: \n" , Valid_Transactions['Amount'].describe())
# Out:
# **************************************
# :: Class Distribution ::
# 0    284315
# 1       492
# Name: Class, dtype: int64
# **************************************
# **************************************
# :: Description of Amount for Fraudulent Transactions ::
#  count     492.000000
# mean      122.211321
# std       256.683288
# min         0.000000
# 25%         1.000000
# 50%         9.250000
# 75%       105.890000
# max      2125.870000
# Name: Amount, dtype: float64
# **************************************
# :: Description of Amount for Valid Transactions ::
#  count    284315.000000
# mean         88.291022
# std         250.105092
# min           0.000000
# 25%           5.650000
# 50%          22.000000
# 75%          77.050000
# max       25691.160000
# Name: Amount, dtype: float64

# %% [markdown]
# ## Histograms of each parameter ##

# %%
creditcard_data.hist(figsize = (20, 20))
plt.show()

# %% [markdown]
# ## Correlation matrix ##

# %%
correlation_data = creditcard_data.corr()
fig = plt.figure(figsize = (12, 9))

heatmap = sns.heatmap(correlation_data, vmax = .8, annot=False, square = True, cmap='BrBG')
heatmap.set_title('Correlation Heatmap', fontdict={'fontsize':12}, pad=12);
plt.show()

# %% [markdown]
# ## Splitting the data for training and testing ##

# %%
X = creditcard_data.drop(columns=['Class'], axis=1)
y = creditcard_data['Class']

# %% [markdown]
# ## Scaling the data ##

# %%
#from sklearn.preprocessing import StandardScaler
#sc = StandardScaler()
#X_scaled = sc.fit_transform(X)

# %% [markdown]
# #####################################################################
# ## Training the Model and Predicting on Test data ##
# #####################################################################
#
# Algorithms to be used:
# * Logistic Regression
# * Random Forest
# * XGBoost
# * Ada Boost
#
# Metrics used:
# * Accuracy
# * Precision
# * F1-Score
# * Recall
# * AUC/RUC Curve

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, f1_score
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, confusion_matrix, roc_curve, roc_auc_score

def plot_roc_curve(fpr, tpr, label=None):
    plt.figure(figsize=(8, 6))
    plt.title('ROC Curve', fontsize=15)
    plt.plot([0, 1], [0, 1], 'k--')
    plt.plot(fpr, tpr, linewidth=2, label=label)
    plt.xticks(np.arange(0, 1, 0.05), rotation=90)
    plt.xlabel('False Positive Rates', fontsize=15)
    plt.ylabel('True Positive Rates', fontsize=15)
    plt.legend(loc='best')
    plt.show()

# %% [markdown]
# ## Logistic Regression ##

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression

pipe = Pipeline([('scaler', StandardScaler()), ('clf', LogisticRegression())])

# training
pipe.fit(x_train, y_train)
# testing
y_pred = pipe.predict(x_test)
print(":: Classification Report :: \n", classification_report(y_test, y_pred, labels=[1,2,3]))
print("-------------------------------------------------------------")
print("F1 Score:",f1_score(y_test, y_pred))
print("Accuracy Score:",accuracy_score(y_test, y_pred))
print("-------------------------------------------------------------")

tn, fp, fn, tp = confusion_matrix(y_test, y_pred).ravel()
conf_matrix = pd.DataFrame(
    {
        'Predicted Fraud': [tp, fp],
        'Predicted Not Fraud': [fn, tn]
    }, index=['Fraud', 'Not Fraud'])
heatmap = sns.heatmap(conf_matrix, annot=True)
heatmap.set_title('Confusion Matrix :: LogisticRegression', fontdict={'fontsize':12}, pad=12);

pred_test_prob = pipe.predict_proba(x_test)[:, 1]
fpr, tpr, threshold = roc_curve(y_test, pred_test_prob)
auc = roc_auc_score(y_test, pred_test_prob)
print("Area Under the ROC Curve: ",auc)
plot_roc_curve(fpr=fpr, tpr=tpr, label="AUC = %.3f" % auc)
# Out:
# :: Classification Report ::
#                precision    recall  f1-score   support
#
#            1       0.85      0.60      0.70       113
#            2       0.00      0.00      0.00         0
#            3       0.00      0.00      0.00         0
#
#    micro avg       0.85      0.60      0.70       113
#    macro avg       0.28      0.20      0.23       113
# weighted avg       0.85      0.60      0.70       113
#
# -------------------------------------------------------------
# F1 Score: 0.7046632124352332
# Accuracy Score: 0.9991994606893064
# -------------------------------------------------------------
# Area Under the ROC Curve:  0.9745163018263159

# %% [markdown]
# ## Random Forest ##

# %%
from sklearn.ensemble import RandomForestClassifier

pipe = Pipeline([('scaler', StandardScaler()), ('clf', RandomForestClassifier())])
# training
pipe.fit(x_train, y_train)
# testing
y_pred = pipe.predict(x_test)

print(":: Classification Report :: \n", classification_report(y_test, y_pred, labels=[1,2,3]))
print("-------------------------------------------------------------")
print("F1 Score:",f1_score(y_test, y_pred))
print("Accuracy Score:",accuracy_score(y_test, y_pred))
print("-------------------------------------------------------------")

tn, fp, fn, tp = confusion_matrix(y_test, y_pred).ravel()
conf_matrix = pd.DataFrame(
    {
        'Predicted Fraud': [tp, fp],
        'Predicted Not Fraud': [fn, tn]
    }, index=['Fraud', 'Not Fraud'])
heatmap = sns.heatmap(conf_matrix, annot=True)
heatmap.set_title('Confusion Matrix :: RandomForestClassifier', fontdict={'fontsize':12}, pad=12);

pred_test_prob = pipe.predict_proba(x_test)[:, 1]
fpr, tpr, threshold = roc_curve(y_test, pred_test_prob)
auc = roc_auc_score(y_test, pred_test_prob)
print("Area Under the ROC Curve: ",auc)
plot_roc_curve(fpr=fpr, tpr=tpr, label="AUC = %.3f" % auc)
# Out:
# :: Classification Report ::
#                precision    recall  f1-score   support
#
#            1       0.92      0.81      0.86       113
#            2       0.00      0.00      0.00         0
#            3       0.00      0.00      0.00         0
#
#    micro avg       0.92      0.81      0.86       113
#    macro avg       0.31      0.27      0.29       113
# weighted avg       0.92      0.81      0.86       113
#
# -------------------------------------------------------------
# F1 Score: 0.863849765258216
# Accuracy Score: 0.999592708069998
# -------------------------------------------------------------
# Area Under the ROC Curve:  0.9542468079088696

# %% [markdown]
# ## XGBoost ##

# %%
from xgboost import XGBClassifier

pipe = Pipeline([('scaler', StandardScaler()), ('clf', XGBClassifier())])
# training
pipe.fit(x_train, y_train)
# testing
y_pred = pipe.predict(x_test)

print(":: Classification Report :: \n", classification_report(y_test, y_pred, labels=[1,2,3]))
print("-------------------------------------------------------------")
print("F1 Score:",f1_score(y_test, y_pred))
print("Accuracy Score:",accuracy_score(y_test, y_pred))
print("-------------------------------------------------------------")

tn, fp, fn, tp = confusion_matrix(y_test, y_pred).ravel()
conf_matrix = pd.DataFrame(
    {
        'Predicted Fraud': [tp, fp],
        'Predicted Not Fraud': [fn, tn]
    }, index=['Fraud', 'Not Fraud'])
heatmap = sns.heatmap(conf_matrix, annot=True)
heatmap.set_title('Confusion Matrix :: XGBClassifier', fontdict={'fontsize':12}, pad=12);

pred_test_prob = pipe.predict_proba(x_test)[:, 1]
fpr, tpr, threshold = roc_curve(y_test, pred_test_prob)
auc = roc_auc_score(y_test, pred_test_prob)
print("Area Under the ROC Curve: ",auc)
plot_roc_curve(fpr=fpr, tpr=tpr, label="AUC = %.3f" % auc)
# Out:
# :: Classification Report ::
#                precision    recall  f1-score   support
#
#            1       0.97      0.81      0.88       113
#            2       0.00      0.00      0.00         0
#            3       0.00      0.00      0.00         0
#
#    micro avg       0.97      0.81      0.88       113
#    macro avg       0.32      0.27      0.29       113
# weighted avg       0.97      0.81      0.88       113
#
# -------------------------------------------------------------
# F1 Score: 0.8792270531400965
# Accuracy Score: 0.9996488862672397
# -------------------------------------------------------------
# Area Under the ROC Curve:  0.9820942388433196

# %% [markdown]
# ## AdaBoost ##

# %%
from sklearn.ensemble import AdaBoostClassifier

pipe = Pipeline([('scaler', StandardScaler()), ('clf', AdaBoostClassifier())])
# training
pipe.fit(x_train, y_train)
# testing
y_pred = pipe.predict(x_test)

print(":: Classification Report :: \n", classification_report(y_test, y_pred, labels=[1,2,3]))
print("-------------------------------------------------------------")
print("F1 Score:",f1_score(y_test, y_pred))
print("Accuracy Score:",accuracy_score(y_test, y_pred))
print("-------------------------------------------------------------")

tn, fp, fn, tp = confusion_matrix(y_test, y_pred).ravel()
conf_matrix = pd.DataFrame(
    {
        'Predicted Fraud': [tp, fp],
        'Predicted Not Fraud': [fn, tn]
    }, index=['Fraud', 'Not Fraud'])
heatmap = sns.heatmap(conf_matrix, annot=True)
heatmap.set_title('Confusion Matrix :: AdaBoostClassifier', fontdict={'fontsize':12}, pad=12);

pred_test_prob = pipe.predict_proba(x_test)[:, 1]
fpr, tpr, threshold = roc_curve(y_test, pred_test_prob)
auc = roc_auc_score(y_test, pred_test_prob)
print("Area Under the ROC Curve: ",auc)
plot_roc_curve(fpr=fpr, tpr=tpr, label="AUC = %.3f" % auc)
# Out:
# :: Classification Report ::
#                precision    recall  f1-score   support
#
#            1       0.81      0.72      0.76       113
#            2       0.00      0.00      0.00         0
#            3       0.00      0.00      0.00         0
#
#    micro avg       0.81      0.72      0.76       113
#    macro avg       0.27      0.24      0.25       113
# weighted avg       0.81      0.72      0.76       113
#
# -------------------------------------------------------------
# F1 Score: 0.7605633802816901
# Accuracy Score: 0.999283727985169
# -------------------------------------------------------------
# Area Under the ROC Curve:  0.9844864788087524

# %% [markdown]
# #####################################################################
# ## Comparing Models using GridSearchCV
# #####################################################################

# %%
model_params = {
    'Random Forest': {
        'model': RandomForestClassifier(),
        'params' : {
            'clf__n_estimators': [1,5,10]
        }
    },
    'Logistic Regression' : {
        'model': LogisticRegression(),
        'params': {
            'clf__C': [1,5,10]
        }
    },
    'XGBoost': {
        'model': XGBClassifier(),
        'params' : { 'clf__max_depth': [3,6,10],
           'clf__learning_rate': [0.01, 0.05, 0.1],
           'clf__n_estimators': [1, 5, 10],
           'clf__colsample_bytree': [0.3, 0.7]}
    },
    'AdaBoost' : {
        'model': AdaBoostClassifier(),
        'params': {
            'clf__learning_rate': [0.01, 0.05, 0.1],
            'clf__n_estimators': [1, 5, 10]
        }
    }
}

# %%
from sklearn.model_selection import GridSearchCV

scores = []

for model_name, mp in model_params.items():
    pipe = Pipeline([('scaler', StandardScaler()), ('clf', mp['model'])])
    clf =  GridSearchCV(pipe, mp['params'], cv=5, return_train_score=False)
    clf.fit(x_train, y_train)
    scores.append({
        'model': model_name,
        'best_score': clf.best_score_,
        'best_params': clf.best_params_
    })

df = pd.DataFrame(scores,columns=['model','best_score','best_params'])
df
# Out:
#                  model  best_score  \
# 0        Random Forest    0.999471
# 1  Logistic Regression    0.999232
# 2              XGBoost    0.999490
# 3             AdaBoost    0.999096
#
#                                          best_params
# 0                          {'clf__n_estimators': 10}
# 1                                     {'clf__C': 10}
# 2  {'clf__colsample_bytree': 0.7, 'clf__learning_...
# 3  {'clf__learning_rate': 0.01, 'clf__n_estimator...

# %% [markdown]
# #####################################################################
# ## Handling Class Imbalance Problem ##
# #####################################################################

# %%
sns.countplot(y_train)
# Out:
# <AxesSubplot:xlabel='Class', ylabel='count'>

# %%
from imblearn.over_sampling import SMOTE
over_sample = SMOTE()
#x_smote, y_smote = over_sample.fit_resample(x_train, y_train)
x_smote, y_smote = over_sample.fit_resample(X, y)
x_train, x_test, y_train, y_test = train_test_split(x_smote, y_smote, test_size=0.25, random_state=42)

# %% [markdown]
# ## Logistic Regression ##

# %%
from sklearn.linear_model import LogisticRegression

pipe = Pipeline([('scaler', StandardScaler()), ('clf', LogisticRegression())])
# training
pipe.fit(x_train, y_train)
# testing
y_pred = pipe.predict(x_test)


print("-------------------------------------------------------------")
print("Accuracy Score:",accuracy_score(y_test, y_pred))
print("-------------------------------------------------------------")
# Out:
# -------------------------------------------------------------
# Accuracy Score: 0.980395053391297
# -------------------------------------------------------------

# %% [markdown]
# ## Random Forest ##

# %%
from sklearn.ensemble import RandomForestClassifier

pipe = Pipeline([('scaler', StandardScaler()), ('clf', RandomForestClassifier())])
# training
pipe.fit(x_train, y_train)
# testing
y_pred = pipe.predict(x_test)

print("-------------------------------------------------------------")
print("Accuracy Score:",accuracy_score(y_test, y_pred))
print("-------------------------------------------------------------")
# Out:
# -------------------------------------------------------------
# Accuracy Score: 0.9999015180292351
# -------------------------------------------------------------

# %% [markdown]
# ## XGBoost ##

# %%
from xgboost import XGBClassifier

pipe = Pipeline([('scaler', StandardScaler()), ('clf', XGBClassifier())])
# training
pipe.fit(x_train, y_train)
# testing
y_pred = pipe.predict(x_test)

print("-------------------------------------------------------------")
print("Accuracy Score:",accuracy_score(y_test, y_pred))
print("-------------------------------------------------------------")
# Out:
# -------------------------------------------------------------
# Accuracy Score: 0.9998522770438526
# -------------------------------------------------------------

# %% [markdown]
# ## Ada Boost ##

# %%
from sklearn.ensemble import AdaBoostClassifier

pipe = Pipeline([('scaler', StandardScaler()), ('clf', AdaBoostClassifier())])
# training
pipe.fit(x_train, y_train)
# testing
y_pred = pipe.predict(x_test)

print("-------------------------------------------------------------")
print("Accuracy Score:",accuracy_score(y_test, y_pred))
print("-------------------------------------------------------------")
# Out:
# -------------------------------------------------------------
# Accuracy Score: 0.9807538091419407
# -------------------------------------------------------------

# %% [markdown]
# #####################################################################
# ## Detecting Anomalies in the data ##
# #####################################################################

# %%
from sklearn.ensemble import IsolationForest

outlier_fraction = len(Fraudulent_Transactions)/float(len(Valid_Transactions))

x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

ifc=IsolationForest(max_samples=len(x_train),
                    contamination=outlier_fraction,random_state=1)
ifc.fit(x_train)
scores_pred = ifc.decision_function(x_train)
y_pred = ifc.predict(x_test)


# Reshape the prediction values to 0 for valid, 1 for fraud.
y_pred[y_pred == 1] = 0
y_pred[y_pred == -1] = 1

n_errors = (y_pred != y_test).sum()
#evaluation of the model
#printing every score of the classifier
#scoring in any thing
from sklearn.metrics import confusion_matrix
n_outliers = len(Fraudulent_Transactions)
print("the Model used is {}".format("Isolation Forest"))
acc= accuracy_score(y_test,y_pred)
print("The accuracy is  {}".format(acc))
prec= precision_score(y_test,y_pred)
print("The precision is {}".format(prec))
rec= recall_score(y_test,y_pred)
print("The recall is {}".format(rec))
f1= f1_score(y_test,y_pred)
print("The F1-Score is {}".format(f1))


#printing the confusion matrix
LABELS = ['Normal', 'Fraud']
conf_matrix = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(5, 5))
sns.heatmap(conf_matrix, xticklabels=LABELS,
            yticklabels=LABELS, annot=True, fmt="d");
plt.title("Confusion matrix")
plt.ylabel('True class')
plt.xlabel('Predicted class')
plt.show()

# Run classification metrics
plt.figure(figsize=(9, 7))
print('{}: {}'.format("Isolation Forest", n_errors))
print(accuracy_score(y_test, y_pred))
print(classification_report(y_test, y_pred, labels=[1,2,3]))
# Out:
# the Model used is Isolation Forest
# The accuracy is  0.9980758967444735
# The precision is 0.38461538461538464
# The recall is 0.35398230088495575
# The F1-Score is 0.3686635944700461
# Isolation Forest: 137
# 0.9980758967444735
#               precision    recall  f1-score   support
#
#            1       0.38      0.35      0.37       113
#            2       0.00      0.00      0.00         0
#            3       0.00      0.00      0.00         0
#
#    micro avg       0.38      0.35      0.37       113
#    macro avg       0.13      0.12      0.12       113
# weighted avg       0.38      0.35      0.37       113
